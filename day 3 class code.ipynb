# %%
print("FEIMIFNKDSUJFDPCXKMRGS")
# Out:
# FEIMIFNKDSUJFDPCXKMRGS

# %%
tuple= ("math","it","pysics")
print( tuple)
print(type(tuple))
# Out:
# ('math', 'it', 'pysics')
# <class 'tuple'>

# %%
set ={"arapic","e","it","e"}

print (set)
# Out:
# {'arapic', 'e', 'it'}

# %%
dict = {'name':'moaaz','school':'weschool'}
print(dict)
# Out:
# {'name': 'moaaz', 'school': 'weschool'}

# %%
print(dict.items())
# Out:
# dict_items([('name', 'moaaz'), ('school', 'weschool')])

# %%
print(dict.keys())
# Out:
# dict_keys(['name', 'school'])

# %%
print(dict.values())
# Out:
# dict_values(['moaaz', 'weschool'])

# %%
print( dict['name'] )
# Out:
# moaaz

# %%
data={'name':['moaaz','john','magdy'],'scool':['weschool']}
print(data)
# Out:
# {'name': ['moaaz', 'john', 'magdy'], 'scool': ['weschool']}

# %%
print(data['name'])
# Out:
# ['moaaz', 'john', 'magdy']

# %%
x=10
y=35
if(x < y):
    print('x is greater than y')
elif(x == y):
    print('x equal y')
else:
    print("x is less than y")
# Out:
# x is greater than y

# %%
a=float(input('enter numper'))
# Out:
# enter numper -6

# %%
if (a> 0):
    print('posativ')
elif (a==0):
    print('zero')
else:
    print('nigative')
# Out:
# nigative
